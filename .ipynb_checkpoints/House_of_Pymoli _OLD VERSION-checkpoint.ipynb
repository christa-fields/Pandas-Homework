# %%
# Dependencies
import pandas as pd
import json

# %%
# load JSON
purchase_data_1 ="HeroesOfPymoli/purchase_data.json"
purchase_data_2 ="HeroesOfPymoli/purchase_data2.json"

# %%
# Read with pandas
purchase_data_1_pd = pd.read_json(purchase_data_1)
purchase_data_1_pd.head()
# Out:
#    Age Gender  Item ID                                  Item Name  Price  \
# 0   38   Male      165                Bone Crushing Silver Skewer   3.37
# 1   21   Male      119  Stormbringer, Dark Blade of Ending Misery   2.32
# 2   34   Male      174                            Primitive Blade   2.46
# 3   21   Male       92                               Final Critic   1.36
# 4   23   Male       63                             Stormfury Mace   1.27
#
#              SN
# 0     Aelalis34
# 1        Eolo46
# 2   Assastnya25
# 3  Pheusrical25
# 4        Aela59

# %%
total_players= purchase_data_1_pd.drop_duplicates(subset=["SN","Age","Gender"],keep="last")
len(total_players)
# Out:
# 573

# %%
#######NOTES#############


#purchase_data_1_pd[["Age","Gender", "SN"]]

#print(purchase_data_1_pd.columns.values)

#group = purchase_data_1_pd.groupby(["SN","Age","Gender"]).count()
#group 

#print(pd.unique(purchase_data_1_pd.Age))
#print(pd.unique(purchase_data_1_pd.Gender))
#print(pd.unique(purchase_data_1_pd.SN))

# %%
#OPTION 1
#unique = purchase_data_1_pd[["SN","Age","Gender"]].unique()
#sorted(list(unique))

#OPTION 2
#unique = pd.unique(purchase_data_1_pd[["SN","Age","Gender"]])
#sorted(list(unique))

# %%
#Number of Unique Items
unique_items =list(purchase_data_1_pd['Item Name'].unique())
number_unique_items= len(unique_items)
number_unique_items
# Out:
# 179

# %%
#Average Purchase Price
average_price =purchase_data_1_pd["Price"].mean()
average_price
# Out:
# 2.931192307692303

# %%
#Total Number of Purchases

count_purchases= purchase_data_1_pd["Price"].value_counts()
total_purchases = len(count_purchases)
total_purchases
# Out:
# 152

# %%
#Total Revenue
total_revenue = purchase_data_1_pd["Price"].sum()
total_revenue
# Out:
# 2286.3299999999963

# %%
#Purchasing Analysis (Total)


purchasing_analysis_total = [{"Number of Unique Items":"61","Average Price":"$2.83","Number of Purchases":"78", "Total Revenue":"$222.99"}]

df_purchasing_analysis_total = pd.DataFrame(purchasing_analysis_total)
df_purchasing_analysis_total
# Out:
#   Average Price Number of Purchases Number of Unique Items Total Revenue
# 0         $2.83                  78                     61       $222.99

# %%
#gender_groups_df = purchase_data_1_pd.groupby("Gender")
#gender_groups_df.max()

# %%
#Gender Demographics
#Percentage and Count of Male Players
#Percentage and Count of Female Players
#Percentage and Count of Other / Non-Disclosed


count = gender_groups_df["Gender"].value_counts()
count
# Out:
# Gender                 Gender
# Female                 Female                   136
# Male                   Male                     633
# Other / Non-Disclosed  Other / Non-Disclosed     11
# Name: Gender, dtype: int64

# %%
gender_count = pd.DataFrame(gender_groups_df["Gender"].value_counts())
gender_count
# Out:
#                                              Gender
# Gender                Gender
# Female                Female                    136
# Male                  Male                      633
# Other / Non-Disclosed Other / Non-Disclosed      11

# %%
total_count = gender["Gender"].sum()
total_count


#total_count = pd.DataFrame(gender["Gender"].sum())
# Out:
# 780

# %%
#Percentage of Gender Demographics
#gender["Percentage of Total Players"] = gender_count["Gender"] /total_count * 100


#gender["Percentage of Total Players"] = gender_count/total_count * 100
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-274-79740afb0809> in <module>()
#       6
#       7
# ----> 8 answer = pd.DataFrame(gender_groups_df["Gender"].value_counts()) / pd.DataFrame(gender["Gender"].sum()) * 100
#       9
#      10 answer
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     352                                          copy=False)
#     353             else:
# --> 354                 raise ValueError('DataFrame constructor not properly called!')
#     355
#     356         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
pd.merge(bootcamp_name, recommend_bootcamp, on="BootcampName")

# %%
#VERSION 1

#Player Count: Total Number of Players

total_players_groups_df = purchase_data_1_pd.groupby("SN")
total_players_groups_df.max()
# Out:
#                  Age  Gender  Item ID  \
# SN
# Adairialis76      20    Male       44
# Aduephos78        37    Male      174
# Aeduera68         26    Male      156
# Aela49            25    Male       44
# Aela59            23    Male       63
# Aelalis34         38    Male      172
# Aelin32           24    Male       54
# Aeliriam77        20    Male       32
# Aeliriarin93      20    Male        9
# Aeliru63          22    Male      173
# Aellyria80        25    Male      125
# Aellyrialis39     33    Male      152
# Aellysup38        25    Male      107
# Aelollo59         25    Male      129
# Aenarap34         22  Female       59
# Aenasu69          22    Male      141
# Aeral43           19  Female      124
# Aeral85           25    Male      115
# Aeral97           14    Male       39
# Aeri84            19  Female      115
# Aerillorin70      25    Male      179
# Aerithllora36     29    Male      132
# Aerithnucal56     15    Male      172
# ...

# %%
#VERSION 2

#Player Count: Total Number of Players

#total_players_groups_df = purchase_data_1_pd.groupby(['SN','Gender','Age'] )
#total_players_groups_df.max()
# Out:
#                             Item ID  \
# SN              Gender Age
# Adairialis76    Male   20        44
# Aduephos78      Male   37       174
# Aeduera68       Male   26       156
# Aela49          Male   25        44
# Aela59          Male   23        63
# Aelalis34       Male   38       172
# Aelin32         Male   24        54
# Aeliriam77      Male   20        32
# Aeliriarin93    Male   20         9
# Aeliru63        Male   22       173
# Aellyria80      Male   25       125
# Aellyrialis39   Male   33       152
# Aellysup38      Male   25       107
# Aelollo59       Male   25       129
# Aenarap34       Female 22        59
# Aenasu69        Male   22       141
# Aeral43         Female 19       124
# Aeral85         Male   25       115
# Aeral97         Male   14        39
# Aeri84          Female 19       115
# Aerillorin70    Male   25       179
# Aerithllora36   Male   29       132
# Aerithnucal56   Male   15       172
# Aerithnuphos61  Male   25       172
# ...

# %%
#total_players = purchase_data_1_pd["SN"].count()
#total_players


len(total_players_groups_df)

#total_players = total_players_groups_df[['SN','Gender','Age']].count()
#total_players
# Out:
# 573

# %%
len(purchase_data_1_pd)
# Out:
# 780

# %%
# Read with pandas
#purchase_data_2_pd = pd.read_json(purchase_data_2)
#purchase_data_2_pd.head()
# Out:
#    Age Gender  Item ID                 Item Name  Price          SN
# 0   20   Male       93  Apocalyptic Battlescythe   4.49     Iloni35
# 1   21   Male       12                     Dawne   3.36   Aidaira26
# 2   17   Male        5                Putrid Fan   2.63      Irim47
# 3   17   Male      123         Twilight's Carver   2.55     Irith83
# 4   22   Male      154              Feral Katana   4.11  Philodil43

# %%
#Merge data tables
#purchase_data_df = purchase_data_1_pd.merge(purchase_data_2_pd, how='inner', on='Item ID')
#purchase_data_df
# Out:
#      Age_x Gender_x  Item ID                       Item Name_x  Price_x  \
# 0       34     Male      174                   Primitive Blade     2.46
# 1       37   Female      174                   Primitive Blade     2.46
# 2       37     Male      174                   Primitive Blade     2.46
# 3       21   Female      174                   Primitive Blade     2.46
# 4       15     Male      174                   Primitive Blade     2.46
# 5       20     Male       10                       Sleepwalker     1.73
# 6        7   Female       10                       Sleepwalker     1.73
# 7       15     Male       10                       Sleepwalker     1.73
# 8       25     Male       10                       Sleepwalker     1.73
# 9       30     Male       10                       Sleepwalker     1.73
# 10      31     Male       10                       Sleepwalker     1.73
# 11      25     Male      118  Ghost Reaver, Longsword of Magic     2.77
# ...

# %%
#Player Count: Total Number of Players

#total_players_groups_df = purchase_data_df.groupby("SN_x")
#total_players_groups_df.max()
# Out:
#                 Age_x               Gender_x  Item ID  \
# SN_x
# Adairialis76       20                   Male       44
# Aduephos78         37                   Male      174
# Aeduera68          26                   Male      156
# Aela49             25                   Male       44
# Aelalis34          38                   Male      172
# Aeliriam77         20                   Male       18
# Aeliriarin93       20                   Male        9
# Aeliru63           22                   Male      173
# Aellysup38         25                   Male      107
# Aelollo59          25                   Male      129
# Aerithllora36      29                   Male       68
# Aerithnucal56      15                   Male      172
# Aerithnuphos61     25                   Male      172
# Aesty51            15                   Male       94
# Aethedru70         25                   Male      176
# Aidain51           26                   Male      180
# ...

# %%
total_players = purchase_data_df["SN_x"].value_counts()
total_players
